# %% [markdown]
# ##Bitacora de Ejercicios Unidad 2: Métodos Númericos
# Ejercicios con el Método de Newton y Bisección
#
# Ordenados conforme al archivo en Google Drive
#
# Alumno: Fernando Javier Noh Requena

# %%
# Algoritmo de Bisección

#Ejercicio 1 

import numpy as np

# INGRESO
fx = lambda x: np.tan(x)-3.5

a = float(input("Ingrese el valor de búsqueda a: "))
b = float(input("Ingrese el valor de búsqueda b: "))
tolera = float(input("Ingrese la cota de error"))
print("")

# PROCEDIMIENTO
tabla = []
tramo = b-a

fa = fx(a)
fb = fx(b)
i = 1
while (tramo>tolera):
    c = (a+b)/2
    fc = fx(c)
    tabla.append([i,a,c,b,fa,fc,fb,tramo])
    i = i + 1
                 
    cambia = np.sign(fa)*np.sign(fc)
    if (cambia<0):
        b = c
        fb = fc
    else:
        a=c
        fa = fc
    tramo = b-a
c = (a+b)/2
fc = fx(c)
tabla.append([i,a,c,b,fa,fc,fb,tramo])
tabla = np.array(tabla)

raiz = c

# SALIDA
np.set_printoptions(precision = 4)
print('[ i, a, c, b, f(a), f(c), f(b), tramo]')
# print(tabla)

# Tabla con formato
n=len(tabla)
for i in range(0,n,1):
    unafila = tabla[i]
    formato = '{:.0f}'+' '+(len(unafila)-1)*'{:.3f} '
    unafila = formato.format(*unafila)
    print(unafila)

print("")
print('La raiz es: ',raiz)


# GRAFICA
import matplotlib.pyplot as plt

xi = tabla[:,2]
yi = tabla[:,5]

# ordena los puntos para la grafica
orden = np.argsort(xi)
xi = xi[orden]
yi = yi[orden]

plt.plot(xi,yi)
plt.plot(xi,yi,'o')
plt.axhline(0, color="black")

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bisección en f(x)')
plt.grid()
plt.show()

# %%
# Algoritmo de Bisección

#Ejercicio 4

import numpy as np

# INGRESO
fx = lambda x: np.tan(x)-0.1*x

a = float(input("Ingrese el valor de búsqueda a: "))
b = float(input("Ingrese el valor de búsqueda b: "))
tolera = float(input("Ingrese la cota de error"))
print("")

# PROCEDIMIENTO
tabla = []
tramo = b-a

fa = fx(a)
fb = fx(b)
i = 1
while (tramo>tolera):
    c = (a+b)/2
    fc = fx(c)
    tabla.append([i,a,c,b,fa,fc,fb,tramo])
    i = i + 1
                 
    cambia = np.sign(fa)*np.sign(fc)
    if (cambia<0):
        b = c
        fb = fc
    else:
        a=c
        fa = fc
    tramo = b-a
c = (a+b)/2
fc = fx(c)
tabla.append([i,a,c,b,fa,fc,fb,tramo])
tabla = np.array(tabla)

raiz = c

# SALIDA
np.set_printoptions(precision = 4)
print('[ i, a, c, b, f(a), f(c), f(b), tramo]')
# print(tabla)

# Tabla con formato
n=len(tabla)
for i in range(0,n,1):
    unafila = tabla[i]
    formato = '{:.0f}'+' '+(len(unafila)-1)*'{:.3f} '
    unafila = formato.format(*unafila)
    print(unafila)

print("")
print('La raiz es: ',raiz)


# GRAFICA
import matplotlib.pyplot as plt

xi = tabla[:,2]
yi = tabla[:,5]

# ordena los puntos para la grafica
orden = np.argsort(xi)
xi = xi[orden]
yi = yi[orden]

plt.plot(xi,yi)
plt.plot(xi,yi,'o')
plt.axhline(0, color="black")

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bisección en f(x)')
plt.grid()
plt.show()

# %%
# Algoritmo de Bisección

#Ejercicio 6

import numpy as np

# INGRESO
fx = lambda x: np.tan(x)

a = float(input("Ingrese el valor de búsqueda a: "))
b = float(input("Ingrese el valor de búsqueda b: "))
tolera = float(input("Ingrese la cota de error"))
print("")

# PROCEDIMIENTO
tabla = []
tramo = b-a

fa = fx(a)
fb = fx(b)
i = 1
while (tramo>tolera):
    c = (a+b)/2
    fc = fx(c)
    tabla.append([i,a,c,b,fa,fc,fb,tramo])
    i = i + 1
                 
    cambia = np.sign(fa)*np.sign(fc)
    if (cambia<0):
        b = c
        fb = fc
    else:
        a=c
        fa = fc
    tramo = b-a
c = (a+b)/2
fc = fx(c)
tabla.append([i,a,c,b,fa,fc,fb,tramo])
tabla = np.array(tabla)

raiz = c

# SALIDA
np.set_printoptions(precision = 4)
print('[ i, a, c, b, f(a), f(c), f(b), tramo]')
# print(tabla)

# Tabla con formato
n=len(tabla)
for i in range(0,n,1):
    unafila = tabla[i]
    formato = '{:.0f}'+' '+(len(unafila)-1)*'{:.3f} '
    unafila = formato.format(*unafila)
    print(unafila)

print("")
print('La raiz es: ',raiz)


# GRAFICA
import matplotlib.pyplot as plt

xi = tabla[:,2]
yi = tabla[:,5]

# ordena los puntos para la grafica
orden = np.argsort(xi)
xi = xi[orden]
yi = yi[orden]

plt.plot(xi,yi)
plt.plot(xi,yi,'o')
plt.axhline(0, color="black")

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bisección en f(x)')
plt.grid()
plt.show()

# %%
#Algoritmo de Newton

#Ejercicio 7

import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return x**4-3*x**2-3
  
def Df(x):
  return 4*x**3-6*x
  
x0=int(input("Ingrese el valor inicial: "))
i=1  
error = float(input("Ingrese el valor de la cota de error: "))
while error > 1e-6:
      x1= x0 - f(x0) / Df(x0)
      error = abs(x1-x0)
      x0 = x1
      print("interacion",i," raíz aproximada:",x0)
      i=i+1

x=np.linspace(-2,2,100)
plt.plot(x,f(x))
plt.plot(x0,f(x0),'or')
plt.grid()
plt.show

# %%
#Algoritmo de Newton

#Ejercicio 9

import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return x**2-6
  

def Df(x):
  return 2*x
  

x0=int(input("Ingrese el valor inicial: "))
i=1  
error = float(input("Ingrese el valor de la cota de error: "))
while error > 1e-6:
      x1= x0 - f(x0) / Df(x0)
      error = abs(x1-x0)
      x0 = x1
      print("interacion",i," raíz aproximada:",x0)
      i=i+1

x=np.linspace(-2,2,100)
plt.plot(x,f(x))
plt.plot(x0,f(x0),'or')
plt.grid()
plt.show
